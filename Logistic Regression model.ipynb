# %%
import pandas as pd

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn import feature_extraction 
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
df = pd.read_excel("./OBGYN_new_train_80000.xlsx")
df2 = pd.read_excel("./OBGYN_new_test_withoutAnswer_20000_2024.xlsx")

# %%
def preprocessText(text_lower):
    text_lower = text_lower.lower()
    translator = str.maketrans('', '', string.punctuation)
    text_lower = text_lower.translate(translator)
    words = text_lower.split()
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    return ' '.join(words)

# %%
train_df = df
train_df['review'] = train_df['review'].apply(preprocessText)
train_df.head()
# Out:
#    reviewID  doctorID             doctorName             specialty  \
# 0         1   2320644     Dr. Kevin G. Fahey  Gynecologist (OBGYN)
# 1         2    961169      Dr. Sudha R. Nair  Gynecologist (OBGYN)
# 2         3    876934        Dr. Bonnie Gong  Gynecologist (OBGYN)
# 3         4    102625      Dr. Louann Turner  Gynecologist (OBGYN)
# 4         5     42933  Dr. Michael A. Benson  Gynecologist (OBGYN)
#
#    numReviews           city state  \
# 0           2      New Haven    MI
# 1           5      Knoxville    TN
# 2           6       Kirkland    WA
# 3           6        Suffolk    VA
# 4          21  Staten Island    NY
#
#                                       doctorHomepage  averageRating  staff  \
# 0  /doctor-ratings/2320644/Dr-KEVIN%2BG.-FAHEY-Ne...           4.25      4
# 1  /doctor-ratings/961169/Dr-Sudha%2BR.-Nair-Knox...           2.00      2
# 2  /doctor-ratings/876934/Dr-Bonnie-Gong-Kirkland...           4.00      3
# 3  /doctor-ratings/102625/Dr-Louann-Turner-Suffol...           4.50      4
# 4  /doctor-ratings/42933/Dr-Michael%2BA.-Benson-S...           5.00      5
#
#    punctuality  helpfulness  knowledge          postedTime  \
# 0            3            5          5 2013-06-12 16:00:00
# 1            3            2          1 2010-03-21 16:36:00
# 2            3            5          5 2010-08-12 13:08:00
# 3            4            5          5 2009-07-23 12:09:00
# 4            5            5          5 2008-03-14 16:22:00
#
#                                               review  review_helpful_count
# 0  went doctor close house great share office doc...                     0
# 1  unprofessional knowledgeable office surgical p...                     0
# 2  doctor leave practice due illness disappointed...                     0
# 3  wonderful take time tell exactly thing term un...                     0
# 4  excellent doctor caring considerate excellent ...                     0

# %%
test_df = df2
test_df['review'] = test_df['review'].apply(preprocessText)
test_df.head()
# Out:
#    reviewID  doctorID                doctorName             specialty  \
# 0     80001    106417  Dr. Daniel E. Bahnmiller  Gynecologist (OBGYN)
# 1     80002     31663        Dr. Donald P. Ward  Gynecologist (OBGYN)
# 2     80003   2244002      Dr. James R. Gullett  Gynecologist (OBGYN)
# 3     80004     16966           Dr. Henry Y. Su  Gynecologist (OBGYN)
# 4     80005       919     Dr. Judith A. Gurdian  Gynecologist (OBGYN)
#
#    numReviews       city state  \
# 0          22   Richland    WA
# 1           8     Austin    TX
# 2           2    Houston    TX
# 3          17    HOUSTON    TX
# 4          38  ROCKVILLE    MD
#
#                                       doctorHomepage          postedTime  \
# 0  /doctor-ratings/106417/Dr-Daniel%2BE.-Bahnmill... 2010-09-10 22:00:00
# 1  /doctor-ratings/31663/Dr-Donald%2BP.-Ward-Aust... 2007-01-16 13:13:00
# 2  /doctor-ratings/2244002/Dr-JAMES%2BR.-GULLETT-... 2013-05-26 08:55:00
# 3  /doctor-ratings/16966/Dr-Henry%2BY.-Su-HOUSTON... 2009-05-22 13:57:00
# 4  /doctor-ratings/919/Dr-Judith%2BA.-Gurdian-ROC... 2012-04-13 16:56:00
#
#                                               review  review_helpful_count
# 0  friendly helpful staff doctor doctor listens a...                     0
# 1  dr ward professional time kind thoughtful gent...                     0
# 2  dr gullett excellent doctor staff great especi...                     0
# 3  seems really nice partnred w dr mundy doctor d...                     0
# 4  wonderful doctor high risk patient rare bleedi...                     0

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=3000,ngram_range=(1, 2))
X_train_tfidf = tfidf_vectorizer.fit_transform(train_df['review'])
y = (train_df['knowledge'] == 5).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf, y, test_size=0.2, random_state=42)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.9210625

# %%
test_tfidf = tfidf_vectorizer.transform(test_df['review'])

# %%
prediction = model.predict(test_tfidf)
test_df['prediction'] = prediction

# %%
test_df.head()
# Out:
#    reviewID  doctorID                doctorName             specialty  \
# 0     80001    106417  Dr. Daniel E. Bahnmiller  Gynecologist (OBGYN)
# 1     80002     31663        Dr. Donald P. Ward  Gynecologist (OBGYN)
# 2     80003   2244002      Dr. James R. Gullett  Gynecologist (OBGYN)
# 3     80004     16966           Dr. Henry Y. Su  Gynecologist (OBGYN)
# 4     80005       919     Dr. Judith A. Gurdian  Gynecologist (OBGYN)
#
#    numReviews       city state  \
# 0          22   Richland    WA
# 1           8     Austin    TX
# 2           2    Houston    TX
# 3          17    HOUSTON    TX
# 4          38  ROCKVILLE    MD
#
#                                       doctorHomepage          postedTime  \
# 0  /doctor-ratings/106417/Dr-Daniel%2BE.-Bahnmill... 2010-09-10 22:00:00
# 1  /doctor-ratings/31663/Dr-Donald%2BP.-Ward-Aust... 2007-01-16 13:13:00
# 2  /doctor-ratings/2244002/Dr-JAMES%2BR.-GULLETT-... 2013-05-26 08:55:00
# 3  /doctor-ratings/16966/Dr-Henry%2BY.-Su-HOUSTON... 2009-05-22 13:57:00
# 4  /doctor-ratings/919/Dr-Judith%2BA.-Gurdian-ROC... 2012-04-13 16:56:00
#
#                                               review  review_helpful_count  \
# 0  friendly helpful staff doctor doctor listens a...                     0
# 1  dr ward professional time kind thoughtful gent...                     0
# 2  dr gullett excellent doctor staff great especi...                     0
# 3  seems really nice partnred w dr mundy doctor d...                     0
# 4  wonderful doctor high risk patient rare bleedi...                     0
#
#    prediction
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
submission = test_df[['reviewID','prediction']]
submission.head()
# Out:
#    reviewID  prediction
# 0     80001           1
# 1     80002           1
# 2     80003           1
# 3     80004           1
# 4     80005           1

# %%
submission.to_csv('32641622_wolverine.csv',index=False)
